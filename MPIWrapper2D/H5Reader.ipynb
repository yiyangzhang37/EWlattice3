# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import h5py

# %%
f = h5py.File('one_bubble_den_50.h5','r')
dataset = list(f.keys())[0]
dset = f[dataset]
attrs = list(dset.attrs)

# %% [markdown]
# The dset is ordered as [z,y,x, component].

# %%
f.close()

# %%
dset
# Out:
# <HDF5 dataset "one_bubble_den_1.h5": shape (32, 32, 32, 3), type "<f4">

# %%
plt.imshow(dset[32,:,:,0], interpolation = 'bilinear')
plt.colorbar()
plt.show()

# %%
dset[17,17,16,2], dset[15,15,16,2]
# Out:
# (4.7560987, 4.7560987)

# %%
228+228+178+291
# Out:
# 925

# %%
import numpy as np
arr = np.zeros(128)
for i in range(128):
    arr[i] = np.sin(2.0*3.1415926/128*i)
np.fft.fft(arr)
# Out:
# array([  5.35899099e-08 +0.00000000e+00j,
#         -3.37615699e-06 -6.40000005e+01j,
#          5.35897538e-08 -1.45475261e-06j,
#          5.35897794e-08 -8.17475806e-07j,
#          5.35897856e-08 -5.80496831e-07j,
#          5.35897875e-08 -4.52689672e-07j,
#          5.35897896e-08 -3.71670075e-07j,
#          5.35897839e-08 -3.15343537e-07j,
#          5.35897907e-08 -2.73745887e-07j,
#          5.35897914e-08 -2.41678264e-07j,
#          5.35897914e-08 -2.16147409e-07j,
#          5.35897916e-08 -1.95302160e-07j,
#          5.35897911e-08 -1.77933625e-07j,
#          5.35897919e-08 -1.63217657e-07j,
#          5.35897918e-08 -1.50572467e-07j,
#          5.35897879e-08 -1.39575313e-07j,
#          5.35897937e-08 -1.29911476e-07j,
#          5.35897892e-08 -1.21341650e-07j,
#          5.35897914e-08 -1.13680637e-07j,
#          5.35897936e-08 -1.06782775e-07j,
#          5.35897927e-08 -1.00531928e-07j,
#          5.35897932e-08 -9.48343092e-08j,
# ...
